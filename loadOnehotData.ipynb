# %%
############### Sample code to unpickle and use oneHot encoded data

# run "pip install pickle-mixin" in anaconda prompt or wherever else you do pip install

import pickle
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/MLProject_KenyaFinancial   # Change path to yours 


# For X, you will need to unzip ohc1.zip in clean_data. For y, it is depVar.zip. 
# DON'T USE ohc.zip, it is 16 gb unzipped and is bloated with unusable columns.
# Once you do that, replace the string for x_path and y_path in the code below with the location of the corresponding files in your machine.
# Then you can load it onto python and unpickle it. Xd should be a csr sparse matrix, and Yd a pandas series
x_path = "/content/drive/MyDrive/MLProject_KenyaFinancial/clean_data/ohc1" 
y_path = "/content/drive/MyDrive/MLProject_KenyaFinancial/clean_data/depVar"

with open(x_path, 'rb') as ifile:
  Xd =pickle.load(ifile)
with open(y_path, 'rb') as ifile:
  Yd =pickle.load(ifile)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/drive/MyDrive/MLProject_KenyaFinancial # Change path to yours'
# /content

# %%
Xd.shape
# Out:
# (735849, 3059)

# %%
Yd.shape
# Out:
# (735849,)

# %%
type(Yd)
# Out:
# pandas.core.series.Series

# %%
X = Xd.toarray()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5aec444155ba> in <module>()
# ----> 1 X = Xd.toarray()
#
# NameError: name 'Xd' is not defined
