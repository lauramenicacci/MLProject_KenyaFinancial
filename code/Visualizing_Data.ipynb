# %% [markdown]
# <a href="https://colab.research.google.com/github/lauramenicacci/MLProject_KenyaFinancial/blob/main/Visualizing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial
DATA_PATH = "/content/drive/MyDrive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial/clean_data/official.zip" #replace with your data path
os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial
# '/content/drive/My Drive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial'

# %%
data = pd.read_csv(DATA_PATH)

# %%
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
# Out:
# [Text(0, 0, 'hh_ids'),
#  Text(0, 0, 'account_ids'),
#  Text(0, 0, 'm_ids_owner'),
#  Text(0, 0, 'first_trx_date_acc'),
#  Text(0, 0, 'last_trx_date_acc'),
#  Text(0, 0, 'trx_id'),
#  Text(0, 0, 'm_ids_trx'),
#  Text(0, 0, 'trx_date'),
#  Text(0, 0, 'trx_month'),
#  Text(0, 0, 'trx_year'),
#  Text(0, 0, 'trx_dq_round'),
#  Text(0, 0, 'trx_family_code'),
#  Text(0, 0, 'trx_type_code'),
#  Text(0, 0, 'trx_mode_desc'),
#  Text(0, 0, 'trx_direction'),
#  Text(0, 0, 'trx_value_usd'),
#  Text(0, 0, 'ddd_gift'),
#  Text(0, 0, 'trx_stdtime_mnths_hh_nr'),
#  Text(0, 0, 'dem_urban'),
#  Text(0, 0, 'dem_hh_size'),
#  Text(0, 0, 'dem_hh_meanage'),
#  Text(0, 0, 'dem_hh_ages0_4'),
#  Text(0, 0, 'dem_hh_ages5_14'),
#  Text(0, 0, 'dem_hh_ages15_17'),
#  Text(0, 0, 'dem_hh_ages0_17'),
#  Text(0, 0, 'dem_hh_ages15plus'),
#  Text(0, 0, 'dem_hh_ages18plus'),
#  Text(0, 0, 'dem_hh_ages65plus'),
#  Text(0, 0, 'dem_hh_ages20_30'),
#  Text(0, 0, 'dem_hh_workage'),
#  Text(0, 0, 'dem_hh_dependents'),
#  Text(0, 0, 'dem_hh_agehead'),
#  Text(0, 0, 'dem_hh_malehead'),
#  Text(0, 0, 'dem_pae_oecd'),
#  Text(0, 0, 'dem_pae_kihbs'),
#  Text(0, 0, 'con_prod_hh_medpti'),
#  Text(0, 0, 'edu_hh_child613inschool'),
#  Text(0, 0, 'edu_hh_child1417inschool'),
#  Text(0, 0, 'edu_hh_girls613inschool'),
#  Text(0, 0, 'edu_hh_girls1417inschool'),
#  Text(0, 0, 'edu_hh_boys613inschool'),
#  Text(0, 0, 'edu_hh_boys1417inschool'),
#  Text(0, 0, 'edu_hh_headattain_yrs'),
#  Text(0, 0, 'con_pur_hh_byti_x'),
#  Text(0, 0, 'con_pur_hh_byti_ALC'),
#  Text(0, 0, 'con_pur_hh_byti_CLN'),
#  Text(0, 0, 'con_pur_hh_byti_CLTH'),
#  Text(0, 0, 'con_pur_hh_byti_COMM'),
#  Text(0, 0, 'con_pur_hh_byti_EDU'),
#  Text(0, 0, 'con_pur_hh_byti_ENRGY'),
#  Text(0, 0, 'con_pur_hh_byti_ENT'),
#  Text(0, 0, 'con_pur_hh_byti_FOOD'),
#  Text(0, 0, 'con_pur_hh_byti_H20'),
#  Text(0, 0, 'con_pur_hh_byti_HSNG'),
#  Text(0, 0, 'con_pur_hh_byti_MED'),
#  Text(0, 0, 'con_pur_hh_byti_OTH'),
#  Text(0, 0, 'con_pur_hh_byti_PERS'),
#  Text(0, 0, 'con_pur_hh_byti_REL'),
#  Text(0, 0, 'con_pur_hh_byti_TRNSP'),
#  Text(0, 0, 'inc_hh_byti_x'),
#  Text(0, 0, 'inc_hh_byti_AGRI'),
#  Text(0, 0, 'inc_hh_byti_CITMPC'),
#  Text(0, 0, 'inc_hh_byti_NEINCG'),
#  Text(0, 0, 'inc_hh_byti_REI'),
#  Text(0, 0, 'inc_hh_byti_RIOI'),
#  Text(0, 0, 'inc_hh_byti_RR'),
#  Text(0, 0, 'inc_hh_byti_SEI'),
#  Text(0, 0, 'inc_hh_byti_y'),
#  Text(0, 0, 'con_pur_hh_byti_y'),
#  Text(0, 0, 'con_prod_hh_byti_x'),
#  Text(0, 0, 'dem_urban_x'),
#  Text(0, 0, 'dem_hh_size_x'),
#  Text(0, 0, 'dem_pae_oecd_x'),
#  Text(0, 0, 'dem_pae_kihbs_x'),
#  Text(0, 0, 'con_hh_byti_x'),
#  Text(0, 0, 'inc_hh_byti_pae_oecd_x'),
#  Text(0, 0, 'con_hh_byti_pae_oecd_x'),
#  Text(0, 0, 'inc_hh_byti_pae_kihbs_x'),
#  Text(0, 0, 'con_hh_byti_pae_kihbs_x'),
#  Text(0, 0, 'inc_below_1_usd_oecd_x'),
#  Text(0, 0, 'con_below_1_usd_oecd_x'),
#  Text(0, 0, 'inc_below_1_usd_kihbs_x'),
#  Text(0, 0, 'con_below_1_usd_kihbs_x'),
#  Text(0, 0, 'inc_below_2_usd_oecd_x'),
#  Text(0, 0, 'con_below_2_usd_oecd_x'),
#  Text(0, 0, 'inc_below_2_usd_kihbs_x'),
#  Text(0, 0, 'con_below_2_usd_kihbs_x'),
#  Text(0, 0, 'inc_below_5_usd_oecd_x'),
#  Text(0, 0, 'con_below_5_usd_oecd_x'),
#  Text(0, 0, 'inc_below_5_usd_kihbs_x'),
#  Text(0, 0, 'con_below_5_usd_kihbs_x'),
#  Text(0, 0, 'inc_hh_byti'),
#  Text(0, 0, 'con_pur_hh_byti'),
#  Text(0, 0, 'con_prod_hh_byti_y'),
#  Text(0, 0, 'dem_urban_y'),
#  Text(0, 0, 'dem_hh_size_y'),
#  Text(0, 0, 'dem_pae_oecd_y'),
#  Text(0, 0, 'dem_pae_kihbs_y'),
#  Text(0, 0, 'con_hh_byti_y'),
#  Text(0, 0, 'inc_hh_byti_pae_oecd_y'),
#  Text(0, 0, 'con_hh_byti_pae_oecd_y'),
#  Text(0, 0, 'inc_hh_byti_pae_kihbs_y'),
#  Text(0, 0, 'con_hh_byti_pae_kihbs_y'),
#  Text(0, 0, 'inc_below_1_usd_oecd_y'),
#  Text(0, 0, 'con_below_1_usd_oecd_y'),
#  Text(0, 0, 'inc_below_1_usd_kihbs_y'),
#  Text(0, 0, 'con_below_1_usd_kihbs_y'),
#  Text(0, 0, 'inc_below_2_usd_oecd_y'),
#  Text(0, 0, 'con_below_2_usd_oecd_y'),
#  Text(0, 0, 'inc_below_2_usd_kihbs_y'),
#  Text(0, 0, 'con_below_2_usd_kihbs_y'),
#  Text(0, 0, 'inc_below_5_usd_oecd_y'),
#  Text(0, 0, 'con_below_5_usd_oecd_y'),
#  Text(0, 0, 'inc_below_5_usd_kihbs_y'),
#  Text(0, 0, 'con_below_5_usd_kihbs_y'),
#  Text(0, 0, 'rem_hh_count_byti'),
#  Text(0, 0, 'rem_hh_abs_byti'),
#  Text(0, 0, 'rem_hh_net_byti'),
#  Text(0, 0, 'rem_hh_count_byti_RG'),
#  Text(0, 0, 'rem_hh_abs_byti_RG'),
#  Text(0, 0, 'rem_hh_count_byti_RR'),
#  Text(0, 0, 'rem_hh_abs_byti_RR'),
#  Text(0, 0, 'rem_hh_count_byti_cash'),
#  Text(0, 0, 'rem_hh_abs_byti_cash'),
#  Text(0, 0, 'rem_hh_net_byti_cash'),
#  Text(0, 0, 'rem_hh_count_byti_inkind'),
#  Text(0, 0, 'rem_hh_abs_byti_inkind'),
#  Text(0, 0, 'rem_hh_net_byti_inkind'),
#  Text(0, 0, 'rem_hh_count_byti_mm'),
#  Text(0, 0, 'rem_hh_abs_byti_mm'),
#  Text(0, 0, 'rem_hh_net_byti_mm'),
#  Text(0, 0, 'rem_hh_count_byti_other'),
#  Text(0, 0, 'rem_hh_abs_byti_other'),
#  Text(0, 0, 'rem_hh_net_byti_other'),
#  Text(0, 0, 'm_ids_x'),
#  Text(0, 0, 'wellbeing_q1'),
#  Text(0, 0, 'wellbeing_q2'),
#  Text(0, 0, 'wellbeing_q3'),
#  Text(0, 0, 'wellbeing_q4'),
#  Text(0, 0, 'goingson_q1'),
#  Text(0, 0, 'goingson_q2'),
#  Text(0, 0, 'goingson_q3'),
#  Text(0, 0, 'goingson_q4'),
#  Text(0, 0, 'goingson_q5'),
#  Text(0, 0, 'goingson_q6'),
#  Text(0, 0, 'goingson_q7'),
#  Text(0, 0, 'goingson_q8'),
#  Text(0, 0, 'goingson_q9'),
#  Text(0, 0, 'goingson_q10'),
#  Text(0, 0, 'm_ids_y'),
#  Text(0, 0, 'dem_i_male'),
#  Text(0, 0, 'dem_i_age_yrs'),
#  Text(0, 0, 'dem_i_age_5yrgrp'),
#  Text(0, 0, 'dem_i_age_workage'),
#  Text(0, 0, 'dem_i_relhead'),
#  Text(0, 0, 'dem_i_hhead'),
#  Text(0, 0, 'dem_i_marstat'),
#  Text(0, 0, 'dem_i_tribe'),
#  Text(0, 0, 'dem_i_children_tot'),
#  Text(0, 0, 'dem_i_children_inhh'),
#  Text(0, 0, 'edu_i_enrolled'),
#  Text(0, 0, 'edu_i_attain'),
#  Text(0, 0, 'edu_i_attain_yrs'),
#  Text(0, 0, 'trx_outlet1'),
#  Text(0, 0, 'trx_purpose1')]

# %%
for col_name in data.columns: 
    print(col_name)

# %%
plt.xlim(0, 20)

plt.hist(data['trx_value_usd'], color = 'blue', edgecolor = 'black',
         bins = int(10000))
plt.title('Number of transactions by amount (USD)')
plt.xlabel('Transaction amount (USD)')
plt.ylabel('Number of transactions')
# Out:
# Text(0, 0.5, 'Number of transactions')

# %%
plt.hist(data['trx_month'], color = 'green', edgecolor = 'black',
         bins = 12)
plt.title('Number of transactions by month')
plt.xlabel('Month')
plt.ylabel('Number of transactions')
# Out:
# Text(0, 0.5, 'Number of transactions')

# %%
plt.hist(data['dem_hh_size'], color = 'red', edgecolor = 'black',
         bins = 25)
plt.title('Number of households by household size')
plt.xlabel('Number of people in household')
plt.ylabel('Number of households')
# Out:
# Text(0, 0.5, 'Number of households')
