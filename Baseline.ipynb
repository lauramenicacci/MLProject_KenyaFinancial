# %%
# !pip install import-ipynb

import pickle
from sklearn import preprocessing 

#access drive
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial

y_path= "/content/drive/MyDrive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial/clean_data/depVar"
x_path = "/content/drive/MyDrive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial/clean_data/ohc3df" 

with open(x_path, 'rb') as ifile:
  Xd = pickle.load(ifile)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial

# %%
# %run Splitting_data.ipynb
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/drive/MyDrive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial # Change path to yours'
# /content/drive/MyDrive/GRAD-C24_Machine_Learning/MLProject_KenyaFinancial

# %%
with open(y_path, 'rb') as ifile:
  Yd =pickle.load(ifile)

Yd = Yd.fillna("")
le = preprocessing.LabelEncoder()
Yd = le.fit_transform(Yd)

yNames = []
for i in range(Yd.max()):
  yNames.append(i)
yNames = le.inverse_transform(yNames)

XtrainVal, Xtest, YtrainVal, y_test = train_test_split(Xd, Yd, test_size= 0.2, random_state= 42)
#Xtrain, Xval, y_train, y_val = train_test_split(XtrainVal, YtrainVal, test_size= 0.25, random_state= 42)

##### CHANGE VARIABLE NAMES to match yours

# %%
X_train, X_val, y_train, y_val = training_set(x_path, y_path)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-c57c2232ab1f> in <module>()
# ----> 1 X_train, X_val, y_train, y_val = training_set(x_path, y_path)
#
# <ipython-input-15-2a0ed9bb1ab5> in training_set(x_path, y_path)
#       1 def training_set(x_path, y_path):
# ----> 2   Xd= pd.read_csv(x_path)
#       3   with open(y_path, 'rb') as ifile:
#       4     Yd =pickle.load(ifile)
#       5
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
l = []

for i in y_train.value_counts():
 l.append(i * 100 / len(y_train))

l2 = list(y_train.value_counts().keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f5bf135c0b9b> in <module>()
#       1 l = []
#       2
# ----> 3 for i in y_train.value_counts():
#       4  l.append(i * 100 / len(y_train))
#       5
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
perc_train = pd.DataFrame(list(zip(l, l2)), columns=["percentage", "payment_method"])

perc_train['perc_cum'] = perc_train['percentage'].cumsum()

# %%
print(perc_train)
# Out:
#     percentage                                     payment_method   perc_cum
# 0    85.799836                                               Cash  85.799836
# 1     5.179509                         Purchase on credit/arrears  90.979346
# 2     2.097126  Mobile money transfer (M-PESA, Airtel Money, O...  93.076472
# 3     1.799284          In-kind (trade, good, service--NOT MONEY)  94.875756
# 4     1.473809                                          Automatic  96.349565
# 5     0.880390                                    CLOSING BALANCE  97.229955
# 6     0.362167                                   STARTING BALANCE  97.592122
# 7     0.360582          Transfer into bank, SACCO, or MFI account  97.952703
# 8     0.082445                                     Standing order  98.035148
# 9     0.069081                          Airtime exchange, sambaza  98.104229
# 10    0.021517                              Cheque or money order  98.125746
# ...

# %%
#y_pred = pd.Series(np.asarray(y_pred))
#y_val = pd.Series(y_val)

# %%
from random import random 

y_pred = []

for y in range(147170):
  n = np.random.randint(98151340)
  for index, row in perc_train.iterrows(): 
                    if n < row["perc_cum"]*1000000:
                                         y_pred.append(row["payment_method"])
                                         break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ca92fda4944e> in <module>()
#       5 for y in range(147170):
#       6   n = np.random.randint(98151340)
# ----> 7   for index, row in perc_train.iterrows():
#       8                     if n < row["perc_cum"]*1000000:
#       9                                          y_pred.append(row["payment_method"])
#
# NameError: name 'perc_train' is not defined

# %%
#y_pred = le.transform(y_pred)

print("Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("F1:", metrics.f1_score(y_val, y_pred, average="weighted"))
print("Matthew's correlation coefficient:", metrics.matthews_corrcoef(y_val, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-937e4a436d07> in <module>()
#       1 #y_pred = le.transform(y_pred)
#       2
# ----> 3 print("Accuracy:", metrics.accuracy_score(y_val, y_pred))
#       4 print("F1:", metrics.f1_score(y_val, y_pred, average="weighted"))
#       5 print("Matthew's correlation coefficient:", metrics.matthews_corrcoef(y_val, y_pred))
#
# NameError: name 'metrics' is not defined
